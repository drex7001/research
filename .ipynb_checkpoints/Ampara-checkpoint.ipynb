# %%
# !pip install neuralprophet
# Out:
# Collecting neuralprophet
#   Downloading neuralprophet-0.3.2-py3-none-any.whl (74 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (3.4.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (7.6.5)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (1.3.4)
# Collecting torch>=1.4.0
#   Downloading torch-1.12.1-cp39-cp39-win_amd64.whl (161.8 MB)
# Collecting holidays>=0.11.3.1
#   Downloading holidays-0.15-py3-none-any.whl (181 kB)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (2.8.2)
# Collecting torch-lr-finder>=0.2.1
#   Downloading torch_lr_finder-0.2.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.50.2 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (4.62.3)
# Collecting dataclasses>=0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\ayodh\anaconda3\lib\site-packages (from neuralprophet) (1.20.3)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.11.tar.gz (5.4 MB)
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.2.1-py3-none-any.whl (8.0 kB)
# Collecting hijri-converter
#   Downloading hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->neuralprophet) (7.29.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ayodh\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.1)
# Requirement already satisfied: pickleshare in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.7.5)
# Requirement already satisfied: decorator in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (58.0.4)
# Requirement already satisfied: colorama in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (3.0.20)
# Requirement already satisfied: pygments in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.18.0)
# Requirement already satisfied: backcall in c:\users\ayodh\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ayodh\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ayodh\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\ayodh\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ayodh\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (228)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.3-cp39-cp39-win_amd64.whl (1.4 MB)
# Requirement already satisfied: pytz in c:\users\ayodh\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->neuralprophet) (2021.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ayodh\anaconda3\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayodh\anaconda3\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ayodh\anaconda3\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ayodh\anaconda3\lib\site-packages (from matplotlib>=2.0.0->neuralprophet) (3.0.4)
# Requirement already satisfied: six in c:\users\ayodh\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.0.0->neuralprophet) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ayodh\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ayodh\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ayodh\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (21.2.0)
# Requirement already satisfied: wcwidth in c:\users\ayodh\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.5)
# Requirement already satisfied: typing-extensions in c:\users\ayodh\anaconda3\lib\site-packages (from torch>=1.4.0->neuralprophet) (3.10.0.2)
# Requirement already satisfied: packaging in c:\users\ayodh\anaconda3\lib\site-packages (from torch-lr-finder>=0.2.1->neuralprophet) (21.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ayodh\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.4.5)
# Requirement already satisfied: jinja2 in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\ayodh\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\ayodh\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\ayodh\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\ayodh\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ayodh\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.1.1)
# Requirement already satisfied: testpath in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.7.1)
# Requirement already satisfied: bleach in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ayodh\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.3)
# Requirement already satisfied: async-generator in c:\users\ayodh\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\ayodh\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\ayodh\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.1)
# Building wheels for collected packages: pymeeus
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.11-py3-none-any.whl size=730984 sha256=f4133c30425778270921bf2ca8f1bb2044daa4c716a07f22b088a17fe721d611
#   Stored in directory: c:\users\ayodh\appdata\local\pip\cache\wheels\33\3d\82\4579e9cca41ff991140b2e050bc6df3a38292f26e4fa06b15d
# Successfully built pymeeus
# Installing collected packages: pymeeus, torch, korean-lunar-calendar, hijri-converter, ephem, convertdate, torch-lr-finder, LunarCalendar, holidays, dataclasses, neuralprophet
# Successfully installed LunarCalendar-0.0.9 convertdate-2.4.0 dataclasses-0.6 ephem-4.1.3 hijri-converter-2.2.4 holidays-0.15 korean-lunar-calendar-0.2.1 neuralprophet-0.3.2 pymeeus-0.5.11 torch-1.12.1 torch-lr-finder-0.2.1

# %%
import pandas as pd
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt
import pickle

# %%
df = pd.read_csv('weather_all.csv')
df.head()
# Out:
#           name  datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Polonnaruwa  1/1/2009     28.2     19.9  24.6          29.8          19.9
# 1  Polonnaruwa  1/2/2009     28.1     23.4  26.0          30.2          23.4
# 2  Polonnaruwa  1/3/2009     28.2     21.7  25.6          29.5          21.7
# 3  Polonnaruwa  1/4/2009     28.0     22.0  25.6          30.1          22.0
# 4  Polonnaruwa  1/5/2009     28.6     22.6  25.6          30.9          22.6
#
#    feelslike   dew  humidity  windspeed  winddir  sealevelpressure  \
# 0       25.4  19.1     72.47        5.3     57.0            1011.4
# 1       26.7  20.5     72.23        5.0     39.0            1012.6
# 2       26.6  19.5     69.88        4.7     36.3            1012.2
# 3       27.0  20.7     74.68        7.2    112.3            1011.7
# 4       26.8  21.2     77.25        5.4     97.3            1010.3
#
#    cloudcover  visibility  moonphase
# 0        24.6        18.5       0.11
# 1        31.3        20.0       0.14
# 2        19.9        20.0       0.20
# 3        37.2        20.0       0.25
# 4        41.8        18.9       0.31

# %%
df.name.unique()
# Out:
# array(['Polonnaruwa', 'Jaffna', 'Matara', 'Ratnapura', "Mahaweli'h'",
#        'Ampara', 'Nuwaraeliya', 'Puttalam', 'Anuradhapura', 'Batticaloa',
#        'Matale', 'Moneragala', 'Kandy', 'Hambantota', 'Gampaha',
#        'Kurunegala', 'colombo', 'Vavuniya', 'Trincomalee', 'Mullativu',
#        'Mannar', 'Kalutara', 'Badulla', 'Kilinochchi', 'Kegalle', 'Galle'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'moonphase'],
#       dtype='object')

# %%
Polonnaruwa = df[df['name']=='Polonnaruwa']
Polonnaruwa['datetime'] = pd.to_datetime(Polonnaruwa['datetime'])
Polonnaruwa.head()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\ayodh\AppData\Local\Temp/ipykernel_7556/42828581.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Polonnaruwa['datetime'] = pd.to_datetime(Polonnaruwa['datetime'])
#           name   datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Polonnaruwa 2009-01-01     28.2     19.9  24.6          29.8          19.9
# 1  Polonnaruwa 2009-01-02     28.1     23.4  26.0          30.2          23.4
# 2  Polonnaruwa 2009-01-03     28.2     21.7  25.6          29.5          21.7
# 3  Polonnaruwa 2009-01-04     28.0     22.0  25.6          30.1          22.0
# 4  Polonnaruwa 2009-01-05     28.6     22.6  25.6          30.9          22.6
#
#    feelslike   dew  humidity  windspeed  winddir  sealevelpressure  \
# 0       25.4  19.1     72.47        5.3     57.0            1011.4
# 1       26.7  20.5     72.23        5.0     39.0            1012.6
# 2       26.6  19.5     69.88        4.7     36.3            1012.2
# 3       27.0  20.7     74.68        7.2    112.3            1011.7
# 4       26.8  21.2     77.25        5.4     97.3            1010.3
#
#    cloudcover  visibility  moonphase
# 0        24.6        18.5       0.11
# 1        31.3        20.0       0.14
# 2        19.9        20.0       0.20
# 3        37.2        20.0       0.25
# 4        41.8        18.9       0.31

# %%
plt.plot(Polonnaruwa['datetime'], Polonnaruwa['tempmax'])
plt.show()

# %%
Polonnaruwa['Year'] = Polonnaruwa['datetime'].apply(lambda x: x.year)
Polonnaruwa = Polonnaruwa[Polonnaruwa['Year']<=2019]
plt.plot(Polonnaruwa['datetime'], Polonnaruwa['tempmax'])
plt.show()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\ayodh\AppData\Local\Temp/ipykernel_7556/2085099022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Polonnaruwa['Year'] = Polonnaruwa['datetime'].apply(lambda x: x.year)

# %%
data = Polonnaruwa[['datetime', 'tempmax']] 
data.dropna(inplace=True)
data.columns = ['ds', 'y'] 
data.head()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\ayodh\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#           ds     y
# 0 2009-01-01  28.2
# 1 2009-01-02  28.1
# 2 2009-01-03  28.2
# 3 2009-01-04  28.0
# 4 2009-01-05  28.6

# %%
m = NeuralProphet()

# %%
model = m.fit(data, freq='D', epochs=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7556/1389841174.py in <module>
# ----> 1 model = m.fit(data, freq='D', epochs=1000)
#
# TypeError: fit() got an unexpected keyword argument 'epochs'
