# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
missing_values = ["0"]
df = pd.read_csv("Book1.csv",na_values=missing_values)


# missing_values = ["0"]
# df = pd.read_csv("wdata.csv",na_values=missing_values)
# # df = pd.read_csv("wdata.csv")
# df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# year             0
# sem              0
# city             0
# humidity         0
# winddir          0
# tempmax          0
# tempmin          0
# temp             0
# feelslikemax     0
# dew              0
# feelslike        0
# feelslikemin     0
# windspeed        0
# visibility       0
# moonphase        0
# cloudcover       0
# hec             14
# production      14
# dtype: int64

# %%
df.head()
# Out:
#    year  sem          city   humidity     winddir    tempmax    tempmin  \
# 0  2009    1        Ampara  77.208706  142.910588  30.314118  24.914118
# 1  2009    1  Anuradhapura  76.983765  153.231177  30.619412  24.499412
# 2  2009    1       Badulla  77.996588  210.491765  26.628824  16.753529
# 3  2009    1    Batticaloa  77.824479  132.336810  30.842331  25.957055
# 4  2009    1       colombo  75.642557  172.565341  31.246591  24.432386
#
#         temp  feelslikemax        dew  feelslike  feelslikemin  windspeed  \
# 0  27.862941     35.094118  23.321765  31.041176     25.493529   8.364118
# 1  27.540588     34.736471  22.765294  29.867647     24.797647   6.389412
# 2  21.621765     27.669412  17.192353  21.967059     16.752353   8.430588
# 3  28.476687     36.906748  24.065644  32.544172     27.247853   9.525767
# 4  27.700568     36.069318  22.744318  30.566477     25.180114  20.609091
#
#    visibility  moonphase  cloudcover    hec  production
# 0   19.768235   0.529706   48.948824  381.0      3628.0
# 1   16.625882   0.527059   48.827059  523.0      3892.0
# 2   17.942353   0.528882   52.427647  460.0      3770.0
# 3   20.000000   0.526994   44.647853  142.0       639.0
# 4   12.073864   0.521761   45.026136   30.0       423.0

# %%
# plt.hist(df["production"])
# plt.xlabel("Production")
# plt.ylabel("External Factors")
# plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['city'])
df['city'] = enc.transform(df['city'])
df.head(10)
# Out:
#    year  sem  city   humidity     winddir    tempmax    tempmin       temp  \
# 0  2009    1     0  77.208706  142.910588  30.314118  24.914118  27.862941
# 1  2009    1     1  76.983765  153.231177  30.619412  24.499412  27.540588
# 2  2009    1     2  77.996588  210.491765  26.628824  16.753529  21.621765
# 3  2009    1     3  77.824479  132.336810  30.842331  25.957055  28.476687
# 4  2009    1    25  75.642557  172.565341  31.246591  24.432386  27.700568
# 5  2009    1     4  81.492611  203.768790  11.482166   3.991720   7.675159
# 6  2009    1     5  78.075172  177.028161  23.912644  15.386207  19.507471
# 7  2009    1     6  82.071420  202.193491  29.782840  25.335503  27.446154
# 8  2009    1     7  74.068598  167.715244  30.445122  27.609756  29.173780
# 9  2009    1     8  75.664205  174.212500  31.246023  24.415341  27.690341
#
#    feelslikemax        dew  feelslike  feelslikemin  windspeed  visibility  \
# 0     35.094118  23.321765  31.041176     25.493529   8.364118   19.768235
# 1     34.736471  22.765294  29.867647     24.797647   6.389412   16.625882
# 2     27.669412  17.192353  21.967059     16.752353   8.430588   17.942353
# 3     36.906748  24.065644  32.544172     27.247853   9.525767   20.000000
# 4     36.069318  22.744318  30.566477     25.180114  20.609091   12.073864
# 5      9.991720   4.343312   5.459236      0.843949  26.100000    9.219108
# 6     23.968391  15.239080  19.533333     15.386207   9.295402   17.809770
# 7     35.277515  23.988166  30.533728     26.039053  20.427219   23.910059
# 8     36.021341  23.906707  33.881707     31.065244  13.995732   19.825610
# 9     36.006818  22.739205  30.522727     25.143750  20.605114   11.402841
#
#    moonphase  cloudcover    hec  production
# 0   0.529706   48.948824  381.0      3628.0
# 1   0.527059   48.827059  523.0      3892.0
# 2   0.528882   52.427647  460.0      3770.0
# 3   0.526994   44.647853  142.0       639.0
# 4   0.521761   45.026136   30.0       423.0
# 5   0.518854   54.048408   30.0       423.0
# 6   0.521839   54.884483   30.0       423.0
# 7   0.524615   57.239053  231.0      1635.0
# 8   0.526707   51.249390  325.0      4692.0
# 9   0.521761   45.040341  129.0       835.0

# %%
df.isnull().sum()
# Out:
# year             0
# sem              0
# city             0
# humidity         0
# winddir          0
# tempmax          0
# tempmin          0
# temp             0
# feelslikemax     0
# dew              0
# feelslike        0
# feelslikemin     0
# windspeed        0
# visibility       0
# moonphase        0
# cloudcover       0
# hec             14
# production      14
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# year            0
# sem             0
# city            0
# humidity        0
# winddir         0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# dew             0
# feelslike       0
# feelslikemin    0
# windspeed       0
# visibility      0
# moonphase       0
# cloudcover      0
# hec             0
# production      0
# dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_adc8d_row0_col0, #T_adc8d_row1_col1, #T_adc8d_row2_col2, #T_adc8d_row3_col3, #T_adc8d_row4_col4, #T_adc8d_row5_col5, #T_adc8d_row6_col6, #T_adc8d_row7_col7, #T_adc8d_row8_col8, #T_adc8d_row9_col9, #T_adc8d_row10_col10, #T_adc8d_row11_col11, #T_adc8d_row12_col12, #T_adc8d_row13_col13, #T_adc8d_row14_col14, #T_adc8d_row15_col15, #T_adc8d_row16_col16, #T_adc8d_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_adc8d_row0_col1, #T_adc8d_row5_col0, #T_adc8d_row12_col14 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_adc8d_row0_col2, #T_adc8d_row0_col3, #T_adc8d_row1_col2, #T_adc8d_row5_col12, #T_adc8d_row12_col4, #T_adc8d_row15_col6, #T_adc8d_row15_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_adc8d_row0_col4, #T_adc8d_row0_col13, #T_adc8d_row1_col13 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T
#  [  1.           1.          30.61941176 ...  48.82705882  16.62588235
#   153.2311765 ]
#  [  2.           1.          26.62882353 ...  52.42764706  17.94235294
#   210.4917647 ]
#  ...
#  [ 22.           2.          29.5374269  ...  72.97368421   7.30584795
#   238.6315789 ]
#  [ 23.           2.          31.31676647 ...  65.49401198  19.15628743
#   212.0556886 ]
#  [ 24.           2.          31.60740741 ...  59.93395062  19.87592593
#   186.6666667 ]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=100)

# %%
X_train.shape
# Out:
# (379, 15)

# %%
y_train.shape
# Out:
# (379,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)

# %%
y_pred
# Out:
# array([ 1803.46,  3091.83,  1240.65,  5288.55,  1818.9 ,  1069.13,
#         2034.87,   562.64,  1129.78,  1799.4 ,   732.43,  1274.48,
#         1258.9 ,  1310.  ,  2529.27,   972.76,  2061.82,   980.11,
#         1909.72,  1627.04,  1013.57,  1075.7 ,   464.18,  6033.83,
#         1119.35,  2511.32,  1056.61,  1893.54,   431.68,   517.5 ,
#          570.87,  4659.87,  2740.86,  6326.76,  1807.24,  1633.59,
#         3960.45,  1056.36,  1426.89,   556.66,  1004.27,  1687.03,
#         1009.81,  2244.62,  1223.19,  9661.97,  1582.29,   999.01,
#         1774.42,  3195.15,  2159.76,  1106.85,  1547.94,  1896.85,
#         1903.92,   573.19,  1311.17,  1869.06,  1101.98,   983.9 ,
#         2188.31,  2565.79,  1325.35,   399.3 ,  1010.63,  1367.52,
#          580.79,  2220.5 ,  2984.46,  1262.81,   695.34,   690.68,
#         4055.51,   840.45,  7118.13,  1005.  ,  1911.57,  1182.58,
#         1236.64,  2530.34,  3631.76,   596.19,   962.13,  1340.88,
#         1698.93,  1208.15,  2564.19,  1730.17,  2952.58,   554.61,
#          707.7 ,   433.86,  2692.57,   333.53,  3378.63,   971.52,
#         1547.16,   654.37,  1606.14,   568.36,   597.61,   685.75,
#         3915.01,   727.71,  4861.16,   716.19,  1744.67,   461.3 ,
#         2191.38,  1183.23,   784.52,  3269.31,  3628.14,  1343.09,
#         3815.62,   391.55,   707.21,  1891.67,   550.55,  2256.75,
#         1945.27,   438.04,  3834.98,   634.47,  1158.2 , 10464.21,
#         2983.57])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1142.0699628099655

# %%
# from sklearn.model_selection import GridSearchCV
# rfr = RandomForestRegressor(random_state = 1)
# param_grid = {  'bootstrap': [True], 'max_depth': [5, 10, None], 'max_features': ['auto', 'log2'], 'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15]}
# g_search = GridSearchCV(estimator = rfr, param_grid = param_grid, 

#                           cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)

# %%
# g_search.fit(X_train, y_train);
# print(g_search.best_params_)

# %%
# print(g_search.score(X_test, y_test))

# %%
rf.score(X_test,y_test)
# Out:
# 0.6218176641913015
