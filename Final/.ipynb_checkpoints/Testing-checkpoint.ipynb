# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Book12.csv")

# %%
df.isnull().sum()
# Out:
# year            0
# sem             0
# city            0
# humidity        0
# winddir         0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# dew             0
# feelslike       0
# feelslikemin    0
# windspeed       0
# visibility      0
# moonphase       0
# cloudcover      0
# hec             0
# production      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'sem', 'city', 'humidity', 'winddir', 'tempmax', 'tempmin',
#        'temp', 'feelslikemax', 'dew', 'feelslike', 'feelslikemin', 'windspeed',
#        'visibility', 'moonphase', 'cloudcover', 'hec', 'production'],
#       dtype='object')

# %%
df.head()
# Out:
#    year  sem          city   humidity     winddir    tempmax    tempmin  \
# 0  2009    1        Ampara  77.208706  142.910588  30.314118  24.914118
# 1  2009    1  Anuradhapura  76.983765  153.231177  30.619412  24.499412
# 2  2009    1       Badulla  77.996588  210.491765  26.628824  16.753529
# 3  2009    1    Batticaloa  77.824479  132.336810  30.842331  25.957055
# 4  2009    1       colombo  75.642557  172.565341  31.246591  24.432386
#
#         temp  feelslikemax        dew  feelslike  feelslikemin  windspeed  \
# 0  27.862941     35.094118  23.321765  31.041176     25.493529   8.364118
# 1  27.540588     34.736471  22.765294  29.867647     24.797647   6.389412
# 2  21.621765     27.669412  17.192353  21.967059     16.752353   8.430588
# 3  28.476687     36.906748  24.065644  32.544172     27.247853   9.525767
# 4  27.700568     36.069318  22.744318  30.566477     25.180114  20.609091
#
#    visibility  moonphase  cloudcover  hec  production
# 0   19.768235   0.529706   48.948824  381        3628
# 1   16.625882   0.527059   48.827059  523        3892
# 2   17.942353   0.528882   52.427647  460        3770
# 3   20.000000   0.526994   44.647853  142         639
# 4   12.073864   0.521761   45.026136   30         423

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['city'])
df['city'] = enc.transform(df['city'])
df.head(10)
# Out:
#    year  sem  city   humidity     winddir    tempmax    tempmin       temp  \
# 0  2009    1     0  77.208706  142.910588  30.314118  24.914118  27.862941
# 1  2009    1     1  76.983765  153.231177  30.619412  24.499412  27.540588
# 2  2009    1     2  77.996588  210.491765  26.628824  16.753529  21.621765
# 3  2009    1     3  77.824479  132.336810  30.842331  25.957055  28.476687
# 4  2009    1    25  75.642557  172.565341  31.246591  24.432386  27.700568
# 5  2009    1     4  81.492611  203.768790  11.482166   3.991720   7.675159
# 6  2009    1     5  78.075172  177.028161  23.912644  15.386207  19.507471
# 7  2009    1     6  82.071420  202.193491  29.782840  25.335503  27.446154
# 8  2009    1     7  74.068598  167.715244  30.445122  27.609756  29.173780
# 9  2009    1     8  75.664205  174.212500  31.246023  24.415341  27.690341
#
#    feelslikemax        dew  feelslike  feelslikemin  windspeed  visibility  \
# 0     35.094118  23.321765  31.041176     25.493529   8.364118   19.768235
# 1     34.736471  22.765294  29.867647     24.797647   6.389412   16.625882
# 2     27.669412  17.192353  21.967059     16.752353   8.430588   17.942353
# 3     36.906748  24.065644  32.544172     27.247853   9.525767   20.000000
# 4     36.069318  22.744318  30.566477     25.180114  20.609091   12.073864
# 5      9.991720   4.343312   5.459236      0.843949  26.100000    9.219108
# 6     23.968391  15.239080  19.533333     15.386207   9.295402   17.809770
# 7     35.277515  23.988166  30.533728     26.039053  20.427219   23.910059
# 8     36.021341  23.906707  33.881707     31.065244  13.995732   19.825610
# 9     36.006818  22.739205  30.522727     25.143750  20.605114   11.402841
#
#    moonphase  cloudcover  hec  production
# 0   0.529706   48.948824  381        3628
# 1   0.527059   48.827059  523        3892
# 2   0.528882   52.427647  460        3770
# 3   0.526994   44.647853  142         639
# 4   0.521761   45.026136   30         423
# 5   0.518854   54.048408   30         423
# 6   0.521839   54.884483   30         423
# 7   0.524615   57.239053  231        1635
# 8   0.526707   51.249390  325        4692
# 9   0.521761   45.040341  129         835

# %%
df.isnull().sum()
# Out:
# year            0
# sem             0
# city            0
# humidity        0
# winddir         0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# dew             0
# feelslike       0
# feelslikemin    0
# windspeed       0
# visibility      0
# moonphase       0
# cloudcover      0
# hec             0
# production      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'sem', 'city', 'humidity', 'winddir', 'tempmax', 'tempmin',
#        'temp', 'feelslikemax', 'dew', 'feelslike', 'feelslikemin', 'windspeed',
#        'visibility', 'moonphase', 'cloudcover', 'hec', 'production'],
#       dtype='object')

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# year            0
# sem             0
# city            0
# humidity        0
# winddir         0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# dew             0
# feelslike       0
# feelslikemin    0
# windspeed       0
# visibility      0
# moonphase       0
# cloudcover      0
# hec             0
# production      0
# dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_08343_row0_col0, #T_08343_row1_col1, #T_08343_row2_col2, #T_08343_row3_col3, #T_08343_row4_col4, #T_08343_row5_col5, #T_08343_row6_col6, #T_08343_row7_col7, #T_08343_row8_col8, #T_08343_row9_col9, #T_08343_row10_col10, #T_08343_row11_col11, #T_08343_row12_col12, #T_08343_row13_col13, #T_08343_row14_col14, #T_08343_row15_col15, #T_08343_row16_col16, #T_08343_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_08343_row0_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_08343_row0_col2, #T_08343_row1_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_08343_row0_col3, #T_08343_row4_col13, #T_08343_row5_col14, #T_08343_row7_col14, #T_08343_row9_col12, #T_08343_row9_col15, #T_08343_row11_col14, #T_08343_row12_col10, #T_08343_row15_col11, #T_08343_row15_col17 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_08343_row0_col4, #T_08343_row13_col3, #T_08343_row16_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_08343_row0_col5, #T_08343_row0_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_08343_row0_col6, #T_08343_row0_col9, #T_08343_row14_col2, #T_08343_row14_col7, #T_08343_row15_col14 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_08343_row0_col7, #T_08343_row1_col10, #T_08343_row12_col0, #T_08343_row14_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_08343_row0_col10, #T_08343_row7_col0, #T_08343_row8_col12 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_08343_row0_col11, #T_08343_row1_col16, #T_08343_row14_col4, #T_08343_row14_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_08343_row0_col12, #T_08343_row14_col13 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_08343_row0_col13, #T_08343_row13_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T
col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_08343_row5_col0, #T_08343_row10_col12, #T_08343_row16_col14 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_08343_row5_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_08343_row5_col4, #T_08343_row6_col16, #T_08343_row7_col4, #T_08343_row11_col16, #T_08343_row16_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_08343_row5_col6, #T_08343_row11_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_08343_row5_col7, #T_08343_row6_col7, #T_08343_row6_col10, #T_08343_row7_col5, #T_08343_row9_col8, #T_08343_row10_col6, #T_08343_row10_col9, #T_08343_row10_col11 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_08343_row5_col8, #T_08343_row7_col9, #T_08343_row8_col10, #T_08343_row9_col7, #T_08343_row10_col8 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_08343_row5_col9, #T_08343_row5_col10, #T_08343_row9_col5, #T_08343_row10_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_08343_row5_col11 {
#   background-color: #d24b40;

# %%
X = df[['city', 'sem','tempmax','tempmin','temp','feelslikemax','feelslikemin','feelslike','dew','humidity','windspeed','moonphase','cloudcover','visibility','winddir','hec']].values

y = df['production'].values

# %%
print(X)
# Out:
# [[  0.           1.          30.31411765 ...  19.76823529 142.9105882
#   381.        ]
#  [  1.           1.          30.61941176 ...  16.62588235 153.2311765
#   523.        ]
#  [  2.           1.          26.62882353 ...  17.94235294 210.4917647
#   460.        ]
#  ...
#  [ 22.           2.          29.5374269  ...   7.30584795 238.6315789
#   127.        ]
#  [ 23.           2.          31.31676647 ...  19.15628743 212.0556886
#    44.        ]
#  [ 24.           2.          31.60740741 ...  19.87592593 186.6666667
#    75.        ]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=26)

# %%
X_train.shape
# Out:
# (390, 16)

# %%
y_train.shape
# Out:
# (390,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)

# %%
y_pred
# Out:
# array([5.361100e+02, 1.711290e+03, 5.865500e+02, 3.651800e+02,
#        4.874400e+02, 1.810700e+02, 6.193900e+02, 6.575800e+02,
#        5.471000e+01, 7.810000e+02, 5.466300e+02, 2.176600e+03,
#        3.236070e+03, 4.530000e+00, 2.163260e+03, 1.944010e+03,
#        8.747000e+02, 9.364710e+03, 5.987500e+02, 2.291020e+03,
#        1.045000e+01, 4.222500e+02, 5.682990e+03, 5.439120e+03,
#        1.076330e+03, 1.434050e+03, 4.255100e+02, 1.196970e+03,
#        1.899110e+03, 1.842200e+02, 3.992300e+02, 4.318600e+02,
#        7.493300e+02, 1.538790e+03, 1.021360e+03, 2.055540e+03,
#        6.287800e+02, 1.441480e+03, 1.239070e+03, 6.607600e+02,
#        2.440700e+03, 2.673800e+02, 2.644940e+03, 1.438570e+03,
#        1.216520e+03, 1.864350e+03, 1.342840e+03, 1.103590e+03,
#        3.520300e+03, 2.541210e+03, 1.404400e+03, 9.677000e+02,
#        2.275090e+03, 2.813500e+02, 5.914800e+02, 1.857630e+03,
#        9.086200e+02, 8.394500e+02, 2.153320e+03, 2.459910e+03,
#        1.077220e+03, 2.392230e+03, 5.598100e+02, 5.198400e+02,
#        5.045300e+02, 2.349060e+03, 5.109300e+02, 4.249100e+02,
#        2.933100e+02, 3.116720e+03, 8.963200e+02, 1.995500e+03,
#        1.872000e+01, 5.241400e+02, 2.727930e+03, 3.845700e+02,
#        4.870600e+02, 4.784000e+02, 1.072480e+03, 5.986000e+02,
#        1.646800e+02, 5.618600e+02, 7.786900e+02, 7.955300e+02,
#        5.141700e+02, 4.071240e+03, 1.750200e+02, 5.105690e+03,
#        4.339200e+02, 1.857420e+03, 3.503000e+02, 1.046920e+03,
#        2.068110e+03, 2.392390e+03, 5.277700e+02, 7.453400e+02,
#        1.539340e+03, 1.126010e+03, 5.673700e+03, 8.526600e+02,
#        1.114170e+03, 1.116320e+03, 2.379630e+03, 6.149300e+02,
#        1.684020e+03, 1.247970e+03, 2.139520e+03, 1.079110e+03,
#        4.515400e+02, 1.181990e+03, 9.413500e+02, 1.460080e+03,
#        8.775800e+02, 9.249200e+02, 4.449700e+02, 1.127900e+03,
#        6.254300e+02, 1.083209e+04, 1.310270e+03, 1.738500e+03,
#        1.213500e+03, 4.085800e+02, 9.461900e+02, 1.228990e+03,
#        2.163930e+03, 1.043490e+03, 1.832880e+03, 1.246570e+03,
#        4.188300e+02, 1.622300e+02])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 516.7264647545085

# %%
rf.score(X_test,y_test)
# Out:
# 0.8807033144643828

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.model_selection import learning_curve

# %%
# train_sizes, train_scores, test_scores = learning_curve(RandomForestRegressor(), X, y, cv=10, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.01, 1.0, 50))
# print(train_sizes,train_scores,test_scores)

# %%
# train_mean = np.mean(train_scores, axis=1)
# train_std = np.std(train_scores, axis=1)

# test_mean = np.mean(test_scores, axis=1)
# test_std = np.std(test_scores, axis=1)

# print(train_mean,train_std,test_mean,test_std)

# %%
# plt.subplots(1, figsize=(10,10))
# plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
# plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
# plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# plt.title("Learning Curve")
# plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import roc_curve,auc
# false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
# roc_auc = auc(false_positive_rate,true_positive_rate)
# roc_auc

# %%
# n_estimators = [1,4,8,16,64,128,256,512,600]
# train_results = []
# test_results = []

# %%
# for estimator in n_estimators:
#     rf = RandomForestClassifier(n_estimators = estimator, n_jobs = -1)
#     rf.fit(X_train,y_train)
#     train_pred = rf.predict(X_train)
#     false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train,train_pred)
#     roc_auc = auc(false_positive_rate,true_positive_rate)
#     train_results.append(roc_auc)
#     y_pred = rf.predict(X_test)
#     false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,y_pred)
#     roc_auc = auc(false_positive_rate,true_positive_rate)
#     test_results.append(roc_auc)

# %%
# define the tree depths to evaluate
values = [i for i in range(1, 21)]


# evaluate a decision tree for each depth
for i in values:
    # configure the model
    model = RandomForestRegressor(n_estimators=i)
    # fit model on the training dataset
    model.fit(X_train, y_train)
    # evaluate on the train dataset
    train_yhat = model.predict(X_train)
    train_acc = rf.score(X_test,y_test)
    train_scores.append(train_acc)
    # evaluate on the test dataset
    test_yhat = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_yhat)
    test_scores.append(test_acc)
    # summarize progress
    print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10532/3389401761.py in <module>
#      12         train_yhat = model.predict(X_train)
#      13         train_acc = rf.score(X_test,y_test)
# ---> 14         train_scores.append(train_acc)
#      15         # evaluate on the test dataset
#      16         test_yhat = model.predict(X_test)
#
# NameError: name 'train_scores' is not defined
