# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Production Forecasting.ipynb', 'wdata.csv', 'weather data.ipynb', 'weather_data.xlsx']

# %%
missing_values = ["0"]
df = pd.read_csv("wdata.csv",na_values=missing_values)
# df = pd.read_csv("wdata.csv")
df.isnull().sum()
# Out:
# name                    0
# datetime                0
# tempmax               171
# tempmin               203
# temp                  166
# feelslikemax          177
# feelslikemin          170
# feelslike             166
# dew                   167
# humidity              162
# precip              14230
# precipcover         12900
# windspeed             355
# winddir               234
# sealevelpressure     2387
# cloudcover            325
# visibility            162
# moonphase             910
# dtype: int64

# %%
df = df.drop(columns=['precip', 'precipcover','sealevelpressure','moonphase'])

# %%
df.dropna(subset = ["temp","feelslike","tempmax","tempmin","windspeed","cloudcover","dew","winddir","feelslikemax","feelslikemin"], inplace=True)

# %%
df
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0      Polonnaruwa    1/1/2016     28.1     25.1  26.2          32.2
# 1      Polonnaruwa    1/2/2016     27.2     24.4  25.6          30.5
# 2      Polonnaruwa    1/3/2016     29.5     24.2  26.5          33.9
# 3      Polonnaruwa    1/4/2016     29.3     24.6  26.7          33.9
# 4      Polonnaruwa    1/5/2016     29.0     25.0  26.7          34.4
# ...            ...         ...      ...      ...   ...           ...
# 28484        Galle  12/26/2018      5.0      3.0   4.0           1.3
# 28485        Galle  12/27/2018      7.0      3.0   4.7           3.8
# 28486        Galle  12/28/2018      5.0      1.0   3.3           1.0
# 28488        Galle  12/30/2018      7.0      5.0   6.2           3.2
# 28489        Galle  12/31/2018      7.0      5.0   6.2           5.2
#
#        feelslikemin  feelslike   dew  humidity  windspeed  winddir  \
# 0              25.1       27.2  23.7     85.86       10.3     50.1
# ...

# %%
df.isnull().sum()
# Out:
# name            0
# datetime        0
# tempmax         0
# tempmin         0
# temp            0
# feelslikemax    0
# feelslikemin    0
# feelslike       0
# dew             0
# humidity        0
# windspeed       0
# winddir         0
# cloudcover      0
# visibility      0
# dtype: int64

# %%
df
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0      Polonnaruwa    1/1/2016     28.1     25.1  26.2          32.2
# 1      Polonnaruwa    1/2/2016     27.2     24.4  25.6          30.5
# 2      Polonnaruwa    1/3/2016     29.5     24.2  26.5          33.9
# 3      Polonnaruwa    1/4/2016     29.3     24.6  26.7          33.9
# 4      Polonnaruwa    1/5/2016     29.0     25.0  26.7          34.4
# ...            ...         ...      ...      ...   ...           ...
# 28484        Galle  12/26/2018      5.0      3.0   4.0           1.3
# 28485        Galle  12/27/2018      7.0      3.0   4.7           3.8
# 28486        Galle  12/28/2018      5.0      1.0   3.3           1.0
# 28488        Galle  12/30/2018      7.0      5.0   6.2           3.2
# 28489        Galle  12/31/2018      7.0      5.0   6.2           5.2
#
#        feelslikemin  feelslike   dew  humidity  windspeed  winddir  \
# 0              25.1       27.2  23.7     85.86       10.3     50.1
# ...

# %%
# sns.heatmap(df.isnull(),yticklabels=False,annot=True)

# %%
# df.to_csv(r'C:\Users\ayodh\OneDrive\Desktop\DATA\my_data.csv', index=False)

# %%
# air_quality = pd.read_csv("data/air_quality_no2_long.csv")

# air_quality = air_quality.rename(columns={"date.utc": "datetime"})

# air_quality.head()

# %%
# df.drop(df.loc[df['tempmax'] <= 14].index, inplace=True)

# %%
# df.drop(df.loc[df['tempmax'] < 40].index, inplace=True)

# %%
df2 = df[~(df['tempmax'] <= 14)]

# %%
df3 = df2[~(df2['tempmax'] >= 40)]

# %%
df3
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0      Polonnaruwa    1/1/2016     28.1     25.1  26.2          32.2
# 1      Polonnaruwa    1/2/2016     27.2     24.4  25.6          30.5
# 2      Polonnaruwa    1/3/2016     29.5     24.2  26.5          33.9
# 3      Polonnaruwa    1/4/2016     29.3     24.6  26.7          33.9
# 4      Polonnaruwa    1/5/2016     29.0     25.0  26.7          34.4
# ...            ...         ...      ...      ...   ...           ...
# 28413        Galle  10/16/2018     18.0     11.0  14.2          18.0
# 28418        Galle  10/21/2018     15.0      6.0   9.8          15.0
# 28427        Galle  10/30/2018     15.0      5.0   8.8          15.0
# 28433        Galle   11/5/2018     15.0      7.0  10.5          15.0
# 28440        Galle  11/12/2018     19.0     10.0  13.2          19.0
#
#        feelslikemin  feelslike   dew  humidity  windspeed  winddir  \
# 0              25.1       27.2  23.7     85.86       10.3     50.1
# ...

# %%
df3.to_csv(r'C:\Users\ayodh\OneDrive\Desktop\DATA\my_data2.csv', index=False)

# %%
district = ["Colombo","Gampaha","Kalutara","Kandy","Matale","Nuwaraeliya","Galle","Matara","Hambantota","Jaffna","Kilinochchi","Mannar","Vavuniya","Mullativu","Batticaloa","Ampara","Trincomalee","Kurunegala","Puttalam","Anuradhapura","Polonnaruwa","Badulla","Moneragala","Ratnapura","Kegalle","Mahaweli'h'"]

# %%
year = [2016,2017,2018]

# %%
# import pymysql
# user = 'root'
# passw = 'root'
# host =  'localhost'
# port = 3306
# database = 'weather'

# %%
# conn = pymysql.connect(host=host,
#                        port=port,
#                        user=user, 
#                        passwd=passw,  
#                        db=database,
#                        charset='utf8')

# df3.to_sql(name=database, con=conn, if_exists = 'replace', index=False)

# %%
# import sql
# from sqlalchemy import create_engine

# # engine = create_engine("mysql+mysqlconnector://root:root@localhost:3306/weather"
# #                        .format(user="root",
# #                                pw="root",
# #                                db="weather"))
# # df.to_sql(con=engine, name='weather', if_exists='replace')

# cnx = mysql.connector.connect(user='root', password='',
#                               host='127.0.0.1', database='weather',
#                               auth_plugin='root')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21120/3820288958.py in <module>
#       8 # df.to_sql(con=engine, name='weather', if_exists='replace')
#       9
# ---> 10 cnx = mysql.connector.connect(user='root', password='',
#      11                               host='127.0.0.1', database='weather',
#      12                               auth_plugin='root')
#
# NameError: name 'mysql' is not defined

# %%
# import sqlalchemy
# import mysql.connector
# database_username = 'root'
# database_password = 'root'
# database_ip       = '127.0.0.1'
# database_name     = 'weather'
# database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
#                                                format(database_username, database_password, 
#                                                       database_ip, database_name))
# df3.to_sql(con=database_connection, name='table_name_for_df', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
# ...

# %%
# mysql+mysqlconnector://[user]:[pass]@[host]:[port]/[schema]
