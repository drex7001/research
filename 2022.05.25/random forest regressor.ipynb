# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final_final_2.csv")

# %%
df.isnull().sum()
# Out:
# season              0
# area(hec)           0
# tempmax             0
# tempmin             0
# temp                0
# feelslikemax        0
# feelslikemin        0
# feelslike           0
# dew                 0
# humidity            0
# windspeed           0
# winddir             0
# sealevelpressure    0
# cloudcover          0
# visibility          0
# production(MT)      0
# dtype: int64

# %%
df.head()
# Out:
#    season  area(hec)    tempmax    tempmin       temp  feelslikemax  \
# 0       1      491.0  31.426257  21.556983  27.377654     35.978212
# 1       2      384.0  30.735119  21.498810  27.035714     35.520833
# 2       1      504.0  32.743094  21.376796  27.580110     37.991160
# 3       2      414.0  30.269022  21.120109  26.505435     34.859783
# 4       1      496.0  31.633523  21.084659  27.017045     36.293750
#
#    feelslikemin  feelslike        dew   humidity  windspeed     winddir  \
# 0     21.556983  29.975978  22.402235  75.672737  20.652514  169.201117
# 1     21.498810  29.496429  23.038690  79.574762  19.487500  187.786905
# 2     21.376796  30.455249  22.895580  77.036298  20.113260  164.210497
# 3     21.120109  28.627717  22.838587  80.983152  19.066304  202.689674
# 4     21.084659  29.450568  22.651136  78.151420  20.335795  165.268750
#
#    sealevelpressure  cloudcover  visibility  production(MT)
# 0       1009.093296   45.236872   11.863128            1695
# 1       1009.424405   57.911310   12.922024            3648
# 2       1009.548619   50.776796   13.509392            1715
# 3       1008.176087   67.685870   13.566304            3929
# 4       1008.642045   60.318750   13.209659            1587

# %%
# plt.hist(df["production(MT)"])
# plt.xlabel("Production")
# plt.ylabel("External Factors")
# plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_fbf77_row0_col0, #T_fbf77_row1_col1, #T_fbf77_row2_col2, #T_fbf77_row3_col3, #T_fbf77_row3_col6, #T_fbf77_row4_col4, #T_fbf77_row5_col5, #T_fbf77_row6_col3, #T_fbf77_row6_col6, #T_fbf77_row7_col7, #T_fbf77_row8_col8, #T_fbf77_row9_col9, #T_fbf77_row10_col10, #T_fbf77_row11_col11, #T_fbf77_row12_col12, #T_fbf77_row13_col13, #T_fbf77_row14_col14, #T_fbf77_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fbf77_row0_col1, #T_fbf77_row0_col8, #T_fbf77_row12_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_fbf77_row0_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_fbf77_row0_col3, #T_fbf77_row0_col6, #T_fbf77_row15_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_fbf77_row0_col4, #T_fbf77_row1_col13 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_fbf77_row0_col5, #T_fbf77_row12_col7, #T_fbf77_row15_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_fbf77_row0_col7, #T_fbf77_row1_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_fbf77_row0_col9, #T_fbf77_row7_col10 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_fbf77_row0_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_fbf77_row0_col11 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T
{
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col5, #T_fbf77_row4_col7, #T_fbf77_row5_col4, #T_fbf77_row5_col7, #T_fbf77_row7_col4, #T_fbf77_row7_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col8, #T_fbf77_row8_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col10, #T_fbf77_row10_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_fbf77_row4_col11, #T_fbf77_row6_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col12, #T_fbf77_row11_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col13, #T_fbf77_row14_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col14, #T_fbf77_row11_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_fbf77_row4_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_fbf77_row5_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_fbf77_row5_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col6 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col10 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_fbf77_row5_col12, #T_fbf77_row6_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col13 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_fbf77_row5_col14, #T_fbf77_row8_col11 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_fbf77_row6_col1, #T_fbf77_row13_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_fbf77_row6_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_fbf77_row6_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_fbf77_row6_col10 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_fbf77_row6_col11, #T_fbf77_row11_col1, #T_fbf77_row11_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_fbf77_row6_col14 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_fbf77_row7_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_fbf77_row7_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_fbf77_row7_col3, #T_fbf77_row7_col6, #T_fbf77_row8_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_fbf77_row7_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_fbf77_row7_col11, #T_fbf77_row14_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_fbf77_row7_col12, #T_fbf77_row7_col14, #T_fbf77_row10_col13 {
#   background-color: #739

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=100)

# %%
x_train.shape
# Out:
# (90, 15)

# %%
y_train.shape
# Out:
# (90,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
y_pred
# Out:
# array([2432.36, 1036.62,  270.12, 1561.25,  328.92,  464.02,  340.81,
#        2156.35,  356.78,  251.51, 3148.73, 1583.81,  500.46,  354.96,
#         224.53, 1312.68,  707.55,  254.26,  355.27, 2400.69,  508.14,
#         736.38,  638.22, 2522.34,  233.7 , 1825.9 , 1186.36,  591.41,
#         252.98,  734.02])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 311138.0551966667

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 557.7975037562168

# %%
# from sklearn.model_selection import GridSearchCV
# rfr = RandomForestRegressor(random_state = 1)
# param_grid = {  'bootstrap': [True], 'max_depth': [5, 10, None], 'max_features': ['auto', 'log2'], 'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15]}
# g_search = GridSearchCV(estimator = rfr, param_grid = param_grid, cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)

# %%
# g_search.fit(X_train, y_train);
# print(g_search.best_params_)

# %%
# print(g_search.score(X_test, y_test))

# %%
rf.score(x_test,y_test)
# Out:
# 0.6714873656500266
