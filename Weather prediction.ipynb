# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather_ampara.csv',low_memory=False)

# %%
df.tail(10)
# Out:
#         name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 3487  Ampara  2018-12-23     26.0     23.4  25.0          26.0          23.4
# 3488  Ampara  2018-12-24     26.9     24.8  25.9          29.9          24.8
# 3489  Ampara  2018-12-25     28.8     27.0  28.1          33.3          30.3
# 3490  Ampara  2018-12-26     29.5     29.5  29.5          34.3          34.3
# 3491  Ampara  2018-12-27     27.8     25.5  27.0          31.2          25.5
# 3492  Ampara  2018-12-28     28.7     24.9  26.9          31.7          24.9
# 3493  Ampara  2018-12-29     28.4     28.4  28.4          31.4          31.4
# 3494  Ampara  2018-12-30     28.4     22.1  25.1          31.3          22.1
# 3495  Ampara  2018-12-31     26.7     26.7  26.7          29.0          29.0
# 3496  Ampara  2019-01-01     27.3     25.4  26.1          29.5          25.4
#
#       feelslike   dew  humidity  windspeed  winddir  sealevelpressure  \
# 3487       25.0  23.6     92.00        4.5    202.3            1011.9
# 3488       27.4  24.0     89.49        9.0    168.0            1011.8
# 3489       32.2  24.3     79.76        9.8    136.7            1011.3
# 3490       34.3  24.0     72.23        6.9     32.0            1012.8
# 3491       29.2  23.4     80.82       13.0    134.7            1011.3
# 3492       28.8  22.9     79.69       12.7     93.2            1010.8
# 3493       31.4  22.3     69.34        7.4     36.0            1013.6
# 3494       26.0  21.5     81.08       13.6    200.0            1014.7
# 3495       29.0  22.8     79.14       13.1     38.0            1013.2
# 3496       26.7  21.3     75.22       15.8    192.8            1015.7
#
#       cloudcover  visibility  moonphase
# 3487        52.5        18.7       0.51
# 3488        66.3        19.6       0.53
# 3489        46.0        20.0       0.55
# 3490        31.6        20.0       0.60
# 3491        63.6        20.0       0.65
# 3492        51.3        19.9       0.70
# 3493        63.6        20.0       0.76
# 3494        39.8        19.7       0.81
# 3495        85.3        20.0       0.86
# 3496        56.3        18.8       0.91

# %%
df.isnull().sum()
# Out:
# name                0
# datetime            0
# tempmax             0
# tempmin             0
# temp                0
# feelslikemax        0
# feelslikemin        0
# feelslike           0
# dew                 0
# humidity            0
# windspeed           0
# winddir             0
# sealevelpressure    0
# cloudcover          0
# visibility          0
# moonphase           0
# dtype: int64

# %%
# count = 0;
# try:
#     df.index = pd.to_datetime(df['datetime'], format='%m.%d.%Y')
# except:
#     count = count + 1
#     print(count)

# %%
# df = df.head(3)

# %%
df.rename(columns = {'datetime':'date'}, inplace = True)

# %%
df
# Out:
#         name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0     Ampara  2009-01-01     27.9     20.0  25.2          29.2          20.0
# 1     Ampara  2009-01-02     28.0     25.7  27.1          29.7          25.7
# 2     Ampara  2009-01-03     28.2     26.1  27.1          29.9          26.1
# 3     Ampara  2009-01-04     28.4     22.6  25.8          31.3          22.6
# 4     Ampara  2009-01-05     28.8     26.4  27.3          31.7          26.4
# ...      ...         ...      ...      ...   ...           ...           ...
# 3492  Ampara  2018-12-28     28.7     24.9  26.9          31.7          24.9
# 3493  Ampara  2018-12-29     28.4     28.4  28.4          31.4          31.4
# 3494  Ampara  2018-12-30     28.4     22.1  25.1          31.3          22.1
# 3495  Ampara  2018-12-31     26.7     26.7  26.7          29.0          29.0
# 3496  Ampara  2019-01-01     27.3     25.4  26.1          29.5          25.4
#
#       feelslike   dew  humidity  windspeed  winddir  sealevelpressure  \
# 0          25.6  19.2     70.72        6.1    122.7            1011.1
# 1          28.2  20.3     66.41        7.8     22.0            1012.5
# 2          28.2  20.4     67.02        8.2     25.0            1012.0
# 3          26.7  21.9     79.79       10.2     87.3            1011.4
# 4          29.3  22.3     74.18       11.2    189.5            1010.2
# ...         ...   ...       ...        ...      ...               ...
# 3492       28.8  22.9     79.69       12.7     93.2            1010.8
# 3493       31.4  22.3     69.34        7.4     36.0            1013.6
# 3494       26.0  21.5     81.08       13.6    200.0            1014.7
# 3495       29.0  22.8     79.14       13.1     38.0            1013.2
# 3496       26.7  21.3     75.22       15.8    192.8            1015.7
#
#       cloudcover  visibility  moonphase
# 0           26.4        20.0       0.11
# 1           18.8        20.0       0.14
# 2           31.4        20.0       0.20
# 3           51.2        20.0       0.25
# 4           68.7        20.0       0.31
# ...          ...         ...        ...
# 3492        51.3        19.9       0.70
# 3493        63.6        20.0       0.76
# 3494        39.8        19.7       0.81
# 3495        85.3        20.0       0.86
# 3496        56.3        18.8       0.91
#
# [3497 rows x 16 columns]

# %%
df.index = pd.to_datetime(df['datetime'], format='%Y %m %d')
# df.index = pd.to_datetime(df['datetime'], format='%m %d %Y',errors='ignore')

# %%
df.dtypes
# Out:
# name                 object
# datetime             object
# tempmax             float64
# tempmin             float64
# temp                float64
# feelslikemax        float64
# feelslikemin        float64
# feelslike           float64
# dew                 float64
# humidity            float64
# windspeed           float64
# winddir             float64
# sealevelpressure    float64
# cloudcover          float64
# visibility          float64
# moonphase           float64
# dtype: object

# %%
temp = df['tempmax']
temp.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((3492, 5, 1), (3492,))

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((3492, 5, 1), (3492,), (0, 5, 1), (0,), (0, 5, 1), (0,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
#  95/110 [========================>.....] - ETA: 0s - loss: 896.2891 - root_mean_squared_error: 29.9381WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 2s 3ms/step - loss: 894.3183 - root_mean_squared_error: 29.9052
# Epoch 2/10
#  99/110 [==========================>...] - ETA: 0s - loss: 831.1005 - root_mean_squared_error: 28.8288WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 826.9010 - root_mean_squared_error: 28.7559
# Epoch 3/10
# 103/110 [===========================>..] - ETA: 0s - loss: 680.7123 - root_mean_squared_error: 26.0905WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 674.2000 - root_mean_squared_error: 25.9654
# Epoch 4/10
# 100/110 [==========================>...] - ETA: 0s - loss: 451.7483 - root_mean_squared_error: 21.2544WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 444.4952 - root_mean_squared_error: 21.0831
# Epoch 5/10
# 106/110 [===========================>..] - ETA: 0s - loss: 301.8423 - root_mean_squared_error: 17.3736WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 3ms/step - loss: 300.9321 - root_mean_squared_error: 17.3474
# Epoch 6/10
#  94/110 [========================>.....] - ETA: 0s - loss: 229.1013 - root_mean_squared_error: 15.1361WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 224.3707 - root_mean_squared_error: 14.9790
# Epoch 7/10
# 101/110 [==========================>...] - ETA: 0s - loss: 164.1272 - root_mean_squared_error: 12.8112WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 162.1318 - root_mean_squared_error: 12.7331
# Epoch 8/10
# 105/110 [===========================>..] - ETA: 0s - loss: 113.5421 - root_mean_squared_error: 10.6556WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 112.7716 - root_mean_squared_error: 10.6194
# Epoch 9/10
# 103/110 [===========================>..] - ETA: 0s - loss: 76.7114 - root_mean_squared_error: 8.7585WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 2ms/step - loss: 75.9799 - root_mean_squared_error: 8.7166
# Epoch 10/10
# 107/110 [============================>.] - ETA: 0s - loss: 51.5521 - root_mean_squared_error: 7.1800WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 110/110 [==============================] - 0s 3ms/step - loss: 51.4214 - root_mean_squared_error: 7.1709

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6684/3528336283.py in <module>
#       1 from tensorflow.keras.models import load_model
# ----> 2 model1 = load_model('model1/')
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     224                 if isinstance(filepath_str, str):
#     225                     if not tf.io.gfile.exists(filepath_str):
# --> 226                         raise IOError(
#     227                             f"No file or directory found at {filepath_str}"
#     228                         )
#
# OSError: No file or directory found at model1/

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 110/110 [==============================] - 0s 963us/step
#       Train Predictions  Actuals
# 0             24.580923     26.9
# 1             24.583996     27.7
# 2             24.582897     26.9
# 3             24.584688     25.1
# 4             24.588278     27.3
# ...                 ...      ...
# 3487          24.583000     28.7
# 3488          24.580009     28.4
# 3489          24.580605     28.4
# 3490          24.581484     26.7
# 3491          24.584080     27.3
#
# [3492 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])
